# %%
# %pip install requests beautifulsoup4  html5lib pandas lxml
#https://krama.karnataka.gov.in/ scrap this
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 38.5 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#https://krama.karnataka.gov.in/ scrap this

import requests
from bs4 import BeautifulSoup
import pandas as pd

# Send a GET request to the website
response = requests.get('https://krama.karnataka.gov.in/')

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

# %%
import pandas as pd

url = "https://krama.karnataka.gov.in/"
tables = pd.read_html(url)  # returns list of DataFrames
df = tables[1]              # pick the first table
print(df.head())
# Out:
#                                                    0  \
# 0  ಉತ್ಪನ್ನಗಳ ಇತ್ತೀಚಿನ ಬೆಲೆಗಳು (*) ಗುರುತಿಸಿದ ಬೆಲೆಗ...
# 1                ಅದರಿಗಾಗಿ ವರದಿ ಮಾಡಲಾದ ಮಾರುಕಟ್ಟೆಗಳು :
# 2                                            ಉತ್ಪನ್ನ
# 3                                            Cereals
# 4                                       Wheat / ಗೋಧಿ
#
#                                                    1  \
# 0  ಉತ್ಪನ್ನಗಳ ಇತ್ತೀಚಿನ ಬೆಲೆಗಳು (*) ಗುರುತಿಸಿದ ಬೆಲೆಗ...
# 1                ಅದರಿಗಾಗಿ ವರದಿ ಮಾಡಲಾದ ಮಾರುಕಟ್ಟೆಗಳು :
# 2                                        ಕನಿಷ್ಠ ಬೆಲೆ
# 3                                                NaN
# 4                                                NaN
#
#                                                    2
# 0  ಉತ್ಪನ್ನಗಳ ಇತ್ತೀಚಿನ ಬೆಲೆಗಳು (*) ಗುರುತಿಸಿದ ಬೆಲೆಗ...
# 1                ಅದರಿಗಾಗಿ ವರದಿ ಮಾಡಲಾದ ಮಾರುಕಟ್ಟೆಗಳು :
# 2                                     ಅತ್ಯುತ್ತಮ ಬೆಲೆ
# 3                                                NaN
# 4                                                NaN

# %%
df
# Out:
#                                                      0  \
# 0    ಉತ್ಪನ್ನಗಳ ಇತ್ತೀಚಿನ ಬೆಲೆಗಳು (*) ಗುರುತಿಸಿದ ಬೆಲೆಗ...
# 1                  ಅದರಿಗಾಗಿ ವರದಿ ಮಾಡಲಾದ ಮಾರುಕಟ್ಟೆಗಳು :
# 2                                              ಉತ್ಪನ್ನ
# 3                                              Cereals
# 4                                         Wheat / ಗೋಧಿ
# ..                                                 ...
# 421                   Suvarnagadde / ಸುವರ್ಣ ಗೆಡ್ಡೆ (*)
# 422                          Lime (Lemon) / ನಿಂಬೆಹಣ್ಣು
# 423                      Lime (Lemon) / ನಿಂಬೆಹಣ್ಣು (*)
# 424                             Bunch Beans / ಗೋರಿಕಾಯಿ
# 425                         Bunch Beans / ಗೋರಿಕಾಯಿ (*)
#
#                                                      1  \
# 0    ಉತ್ಪನ್ನಗಳ ಇತ್ತೀಚಿನ ಬೆಲೆಗಳು (*) ಗುರುತಿಸಿದ ಬೆಲೆಗ...
# 1                  ಅದರಿಗಾಗಿ ವರದಿ ಮಾಡಲಾದ ಮಾರುಕಟ್ಟೆಗಳು :
# 2                                          ಕನಿಷ್ಠ ಬೆಲೆ
# 3                                                  NaN
# ...

# %%
df = df.dropna(how='all')           # remove completely empty rows
df.columns = df.iloc[2]             # use the 3rd row as headers if needed
df = df[3:]                         # drop the header rows
df = df.reset_index(drop=True)
df
# Out:
# 2                             ಉತ್ಪನ್ನ ಕನಿಷ್ಠ ಬೆಲೆ ಅತ್ಯುತ್ತಮ ಬೆಲೆ
# 0                             Cereals         NaN            NaN
# 1                        Wheat / ಗೋಧಿ         NaN            NaN
# 2             Mexican / ಮೆಕ್ಸಿಕನ್ (*)        2460           2541
# 3                      Sona / ಸೋನ (*)        2600           2600
# 4                     Red / ಕೆಂಪು (*)        2900           3475
# ..                                ...         ...            ...
# 418  Suvarnagadde / ಸುವರ್ಣ ಗೆಡ್ಡೆ (*)        2776           4200
# 419         Lime (Lemon) / ನಿಂಬೆಹಣ್ಣು         NaN            NaN
# 420     Lime (Lemon) / ನಿಂಬೆಹಣ್ಣು (*)         300           7500
# 421            Bunch Beans / ಗೋರಿಕಾಯಿ         NaN            NaN
# 422        Bunch Beans / ಗೋರಿಕಾಯಿ (*)        3000           5500
#
# [423 rows x 3 columns]
